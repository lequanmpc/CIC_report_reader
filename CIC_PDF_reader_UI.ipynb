# %%
import pdfplumber
import glob
import os
import re
# import pandas as pd
# from tqdm.notebook import tqdm
import tkinter
from tkinter import filedialog, messagebox, StringVar
# import xlwt
from pandas import DataFrame
import openpyxl
# from datetime import date

# %%
def find_2_5(pdf):
    for i in range(len(pdf.pages)):
            page = pdf.pages[i]
            text = str(page.extract_text())
            text = text.split('\n')
            for j in range(len(text)):
                if text[j].lower().startswith('2.5.'):
    #                 print(text[j])
                    next_line = 1

                    try:
                        while len(text[j+next_line]) < 10:
                            next_line += 1
                        if 'ơn vị tính' in text[j+next_line].lower(): # python doesnot recognize the letter 'đ' in đơn vị
                            next_line +=1

                        a = text[j+next_line]
                        return a
                    except:
                        page_next = pdf.pages[i+1]
                        text_next = str(page_next.extract_text())
                        text_next = text_next.split('\n')
                        
#                         text_next = text_next.split('\n')
                        next_line = 0
                        while len(text_next[next_line]) <9:
                            next_line +=1
                        a_next = text_next[next_line]
                        return a_next
#                         print(a_next)


                elif 'không có thông tin' in text[j].lower():
                    b = 'CIC không có thông tin'
                    return b
#                     print(b)

# def find_id_card(text):# Quan update 01/08/2021 for new format of CIC report, where "số chứng minh nhân dân" inline with the number
#     text = str(text).split('\n')
#     IDcard= []
#     for row in text:
#         if 'số chứng minh' in row.lower() and  re.findall('[0-9]*$',row) != [] and IDcard != [] :
#             try:
#                 id_card = re.findall('[0-9]*$',row)
#     #             print(id_card)
# #                 return id_card[0].strip()
#                 IDcard.append(id_card[0].strip())
#             except:
# #                 return 'can not map ID'
#                 continue
#         elif 'CMT' in row and 'chính xác' in row.lower():
#             try:
#                 id_card = re.findall('.*?([0-9]+)$',row)
# #                 return id_card[0].strip()
#                 IDcard.append(id_card[0].strip())
#             except:
# #                 return 'wrong format/NO CIC'
#                 continue
#     try:
#         return IDcard[0]
#     except:
#         return 'cannot map ID'
    
def find_id_card(pdf):# Quan update 01/08/2021 for new format of CIC report, where "số chứng minh nhân dân" inline with the number

    page = pdf.pages[0] #client id in first page
    text = str(page.extract_text())
    
    text = str(text).split('\n')
    IDcard= []
    for row in text:
        if 'số chứng minh' in row.lower() and  re.findall('[0-9]*$',row) != []:
            try:
                id_card = re.findall('[0-9]*$',row)
                IDcard.append(id_card[0].strip())
            except:
                continue
        elif 'CMT' in row and 'chính xác' in row.lower():
            try:
                id_card = re.findall('.*?([0-9]+)$',row)
                IDcard.append(id_card[0].strip())
            except:
                continue
    try:
        return IDcard[0]
    except:
        return 'cannot map ID'
                

# def find_client_name(text):
#     text = str(text).split('\n') 
#     for row in text:
#         if row.lower().startswith('tên') and 'khách' in row.lower() and ':' in row.lower():
#             try:
#                 client_name = re.findall('(?<=: )[^\]]+',row)[0]
#                 return client_name.strip()
#             except:
#                 return 'Can NOT find name'
#         elif row.lower().startswith('tên') and 'khách' in row.lower() and ':' not in row.lower():
#             try:
                
#                 client_name = re.findall('(?<=Tên khách hàng).*$',row)[0]
# #                 err = 'wrong format file'
# #                 return err
#                 return client_name.strip()
#             except:
#                 return 'Can NOT find name'
        
def find_client_name(pdf):
    page = pdf.pages[0] #client name in first page
    text = str(page.extract_text())
    text = str(text).split('\n')
    
    for row in text:
        if row.lower().startswith('tên') and 'khách' in row.lower() and ':' in row.lower():
            try:
                client_name = re.findall('(?<=: )[^\]]+',row)[0]
                return client_name.strip()
            except:
                return 'Can NOT find name'
        elif row.lower().startswith('tên') and 'khách' in row.lower() and ':' not in row.lower():
            try:
                
                client_name = re.findall('(?<=Tên khách hàng).*$',row)[0]
#                 err = 'wrong format file'
#                 return err
                return client_name.strip()
            except:
                return 'Can NOT find name'


# out_put = {'RA_NAME':[], 'RA_ID':[], 'history_3y':[]}
# data = pd.DataFrame(out_put)

def browse_button():
    # Allow user to select a directory and store it in global var
    # called folder_path
    global saveLocation
    saveLocation = filedialog.askdirectory() +'/'
    entryPath.delete(0,'end')
    entryPath.insert(0,saveLocation)
    #print(saveLocation)

# %%
def read_pdf():
#     today = date.today()
    out_put = []
    total_file = len([x for x in glob.glob(os.path.join(saveLocation, '*.pdf'))])
    cnt = 0
#     for filename in tqdm(glob.glob(os.path.join(saveLocation, '*.pdf'))):
    for filename in glob.glob(os.path.join(saveLocation, '*.pdf')):
        cnt +=1
        short_name = filename.replace(saveLocation[:-1] + '\\', '')
        statusText.set(str(cnt) + '/' + str(total_file) + ':Processing of file #'+ str(short_name))
        status.update()
        print(filename)
        pdf = pdfplumber.open(filename)
        history = find_2_5(pdf)   # Quan fix bug 2.5 next page
        
        # Quan fix 01/08/2021 for new format in CIC: new function
        client_id = find_id_card(pdf) 
        client_name = find_client_name(pdf)
        
        if client_name != None:
            name = client_name
        else:
            name = None

        if client_id != None:
            cid = client_id
        else:
            cid = None

        if history != None:
            if 'không có nợ xấu' in history:
                his =  history
            elif 'không có thông tin' in history:
                his = 'CIC không có thông tin'
            else:
                his = 'NỢ XẤU: vui lòng kiểm tra file PDF'
        else:
            his = 'wrong format/NO CIC'

#         new_row = {'RA_NAME':name, 'RA_ID':cid, 'history_3y':his}
        new_row = {'RA_NAME':name, 'RA_ID':cid, 'history_3y':his, 'filename': short_name}
    #     short_name = os.path.splitext(short_name)[0] #split extension to take only filename
        out_put.append(new_row)

    data = DataFrame(out_put, index = None)
    try:
#         data.to_excel(saveLocation + 'CIC_RESULT_' +str(total_file) + 'files' + '_'+ str(today)+ '.xlsx', encoding = 'utf-8', index = None)
        data.to_excel(saveLocation + 'CIC_RESULT_' +str(total_file) +'_'+ 'files' +'.xlsx', encoding = 'utf-8', index = None)
        messagebox.showinfo(title = "Completed", message = "All file read! Please check file CIC_RESULT.xlsx in your directory!!!")
    except:
        messagebox.showinfo(title = "Error opening file", message = "Please close file CIC_RESULT.xlsx then run again")
    
#     messagebox.showinfo("Completed","All file read! Please check file CIC_RESULT.xlsx in your directory!!!")

# %%
# import openpyxl

# %%
root = tkinter.Tk()
root.geometry("500x350")
root.title("Read CIC file V2")

# root.configure(background='bisque3')

# label1 = tkinter.Label(root, text="skp_client")
# label1.place(x=0, y=30)

# inputBox = tkinter.Text(root, height=20, width=20)
# inputBox.place(x=0, y=50)

# Oracle Username and password
# labelUser = tkinter.Label(root, text="Oracle username:")
# labelUser.place(x=40, y=80)

# inputUser = tkinter.Entry(root, width=40)
# inputUser.place(x=140, y=80)

# labelPassword = tkinter.Label(root, text="Oracle password:")
# labelPassword.place(x=40, y=110)

# inputPassword = tkinter.Entry(root, show="*", width=40)
# inputPassword.place(x=140, y=110)




# # BSL/Cabinet Username and password  -- adding 31/12/2019
# BSL_labelUser = tkinter.Label(root, text="BSL username :")
# BSL_labelUser.place(x=40, y=150)

# BSL_User = tkinter.Entry(root, width=35)
# BSL_User.place(x=140, y=150)

# BSL_labelPassword = tkinter.Label(root, text="BSL password :")
# BSL_labelPassword.place(x=40, y=180)

# BSL_Password = tkinter.Entry(root, show="*", width=35)
# BSL_Password.place(x=140, y=180)



# Save directory
label2 = tkinter.Label(root, text="CIC pdf directory:")
label2.place(x=40, y=70)

entryPath = tkinter.Entry(root, width=40)
global saveLocation
saveLocation = os.path.expanduser('~/Documents/')
entryPath.insert(0,saveLocation)
entryPath.place(x=140, y=70)

btnBrowse = tkinter.Button(root, text = "Browse...", command = browse_button)
btnBrowse.place(x=400, y=70)


btnDownload = tkinter.Button(root, text = "Read PDF CIC", height=3, width=30, command = read_pdf)
btnDownload.place(x=150, y=150)


statusText = StringVar()
status = tkinter.Label(root, textvariable=statusText, borderwidth=2, relief="sunken") 
status.pack(side='bottom') 
# statusText = StringVar()
# status = tkinter.Label(root, textvariable=statusText, borderwidth=2, relief="sunken") 
# status.pack(side='bottom') 

# loginFile = os.path.expanduser('~/Documents/') + 'loginfile.pickle'
# if os.path.exists(loginFile):
#     fileObject = open(loginFile,'rb')  
#     infoList = pickle.load(fileObject)
#     inputUser.insert(0,infoList[0])
#     inputPassword.insert(0,infoList[1])
#     fileObject.close()


root.mainloop()
# Out:
# D:/Data science/CIC_check/2807\BUI ANH TUAN_035200002573_SUCCESS_17.pdf
# D:/Data science/CIC_check/2807\CHU MINH ĐÔNG_060990886_SUCCESS_80.pdf
# D:/Data science/CIC_check/2807\CHU THÚY HƯỜNG_022302004944_SUCCESS_96.pdf
# D:/Data science/CIC_check/2807\DANG NHAT DUY_312488001_SUCCESS_48.pdf
# D:/Data science/CIC_check/2807\DANH THỊ CHANH THI_371890861_SUCCESS_108.pdf
# D:/Data science/CIC_check/2807\HA THI TRANG_175073566_SUCCESS_57.pdf
# D:/Data science/CIC_check/2807\HOÀNG NGỌC DU_073492253_SUCCESS_75.pdf
# D:/Data science/CIC_check/2807\HUỲNH MINH THÔNG_201717335_SUCCESS_117.pdf
# D:/Data science/CIC_check/2807\HUỲNH VĂN MINH_079202004363_SUCCESS_42.pdf
# D:/Data science/CIC_check/2807\HỒ THỊ HỒNG PHƯƠNG_352524867_SUCCESS_64.pdf
# D:/Data science/CIC_check/2807\LE THANH DAT_001098016606_SUCCESS_1.pdf
# D:/Data science/CIC_check/2807\LOC THI TUONG VY_071065017_SUCCESS_28.pdf
# D:/Data science/CIC_check/2807\LUONG NGUYEN DUC HUY_362454480_SUCCESS_112.pdf
# D:/Data science/CIC_check/2807\LÂM THANH HIỂN_025136856_SUCCESS_43.pdf
# D:/Data science/CIC_check/2807\LÊ MINH SANG_352399386_SUCCESS_67.pdf
# D:/Data science/CIC_check/2807\LÊ THỊ HỒNG_251097179_SUCCESS_121.pdf
# D:/Data science/CIC_check/2807\LÙ THẾ VINH_272668913_SUCCESS_58.pdf
# D:/Data science/CIC_check/2807\LƯU THỊ PHƯƠNG THẢO_272634090_SUCCESS_104.pdf
# D:/Data science/CIC_check/2807\LƯƠNG NGỌC HẢI_174185525_SUCCESS_85.pdf
# D:/Data science/CIC_check/2807\LẠI THANH NHÀN_341770801_SUCCESS_14.pdf
# D:/Data science/CIC_check/2807\MAI THỊ KHÁNH LY_194493229_SUCCESS_12.pdf
# D:/Data science/CIC_check/2807\MAI THỊ MỸ LIỄU_194401066_SUCCESS_13.pdf
# D:/Data science/CIC_check/2807\NGO DUC LONG_001096014919_SUCCESS_33.pdf
# D:/Data science/CIC_check/2807\NGUYEN DINH PHONG_037077004045_SUCCESS_10.pdf
# D:/Data science/CIC_check/2807\NGUYEN DUY LONG_001200026613_SUCCESS_22.pdf
# D:/Data science/CIC_check/2807\NGUYEN HA VY_001300033307_SUCCESS_129.pdf
# D:/Data science/CIC_check/2807\NGUYEN NGOC LOAN_026199002917_SUCCESS_23.pdf
# D:/Data science/CIC_check/2807\NGUYEN THI NGOC YEN_301609585_SUCCESS_69.pdf
# D:/Data science/CIC_check/2807\NGUYEN TIEN MANH_172042771_SUCCESS_9.pdf
# D:/Data science/CIC_check/2807\NGUYEN VAN CUONG_013165250_SUCCESS_29.pdf
# D:/Data science/CIC_check/2807\NGUYỄN DUY HƯNG_201745820_SUCCESS_115.pdf
# D:/Data science/CIC_check/2807\NGUYỄN HOÀI THƯƠNG_341843326_SUCCESS_60.pdf
# D:/Data science/CIC_check/2807\NGUYỄN HẢI DUY_101341657_SUCCESS_16.pdf
# D:/Data science/CIC_check/2807\NGUYỄN KIM PHÚC_035200002430_SUCCESS_37.pdf
# D:/Data science/CIC_check/2807\NGUYỄN NGỌC HOÀNG TỊNH_241613625_SUCCESS_125.pdf
# D:/Data science/CIC_check/2807\NGUYỄN PHƯƠNG ANH_113732456_SUCCESS_76.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THANH SƠN_001098015370_SUCCESS_26.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THẾ CHIẾN_212164880_SUCCESS_3.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THỊ HỒNG THẮM_341905636_SUCCESS_61.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THỊ NGỌC OANH_250958534_SUCCESS_101.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THỊ PHƯỢNG_038193014364_SUCCESS_88.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THỊ THU_352192424_SUCCESS_68.pdf
# D:/Data science/CIC_check/2807\NGUYỄN THỊ THUỲ DUNG_187706074_SUCCESS_31.pdf
# D:/Data science/CIC_check/2807\NGUYỄN TIẾN MẠNH_063467628_SUCCESS_32.pdf
# D:/Data science/CIC_check/2807\NGUYỄN VĂN DUY_221516493_SUCCESS_116.pdf
# D:/Data science/CIC_check/2807\NGUYỄN VĂN MINH_341884904_SUCCESS_47.pdf
# D:/Data science/CIC_check/2807\Nguyễn Đức Bá_183551715_SUCCESS_6.pdf
# D:/Data science/CIC_check/2807\NGUYỄN ĐỨC MINH_038089004142_SUCCESS_8.pdf
# D:/Data science/CIC_check/2807\PHAM HOANG GIA BAO_281086009_SUCCESS_15.pdf
# D:/Data science/CIC_check/2807\PHÙ NHỰT NAM_225680568_SUCCESS_119.pdf
# D:/Data science/CIC_check/2807\PHẠM THỊ DIỆU_034302001204_SUCCESS_35.pdf
# D:/Data science/CIC_check/2807\PHẠM THỊ LAN ANH_272809790_SUCCESS_103.pdf
# D:/Data science/CIC_check/2807\PHẠM THỊ THANH VÂN_040300000142_SUCCESS_105.pdf
# D:/Data science/CIC_check/2807\PHẠM TẤN THÀNH_212210563_SUCCESS_5.pdf
# D:/Data science/CIC_check/2807\PHẠM VĨNH TÚ_201690065_SUCCESS_113.pdf
# D:/Data science/CIC_check/2807\QUÁCH HOÀNG HUY_352417346_SUCCESS_63.pdf
# D:/Data science/CIC_check/2807\THI THỊ ANH THƯ_371701394_SUCCESS_107.pdf
# D:/Data science/CIC_check/2807\TRAN SO DIEU_025611317_SUCCESS_73.pdf
# D:/Data science/CIC_check/2807\TRUONG TRI DUC_037200000688_SUCCESS_130.pdf
# D:/Data science/CIC_check/2807\TRƯƠNG THỊ THANH HOÀI_192102470_SUCCESS_114.pdf
# D:/Data science/CIC_check/2807\Trần Hồng Phong_191793101_SUCCESS_11.pdf
# D:/Data science/CIC_check/2807\TRẦN NGỌC SANG_321482226_SUCCESS_106.pdf
# D:/Data science/CIC_check/2807\TRẦN PHAN HOÀI THANH_077197000087_SUCCESS_84.pdf
# D:/Data science/CIC_check/2807\TRẦN THỊ KIM THẢO_371807384_SUCCESS_110.pdf
# D:/Data science/CIC_check/2807\TRẦN THỊ THU LỢI_215315750_SUCCESS_120.pdf
# D:/Data science/CIC_check/2807\Trịnh Hồng Thuận_251034564_SUCCESS_123.pdf
# D:/Data science/CIC_check/2807\TRỊNH ĐÌNH LONG_125943766_SUCCESS_34.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_001099020362_NOT_FOUND_18.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_001186003734_NOT_FOUND_2.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_001200004519_NOT_FOUND_21.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_001201008689_NOT_FOUND_25.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_001302021391_NOT_FOUND_19.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_002197000056_NOT_FOUND_30.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_008099000246_NOT_FOUND_79.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_013680906_NOT_FOUND_24.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_025673209_NOT_FOUND_38.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_030098006066_NOT_FOUND_92.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_031096002785_NOT_FOUND_93.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_031302007228_NOT_FOUND_94.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_034199000203_NOT_FOUND_20.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_034301001268_NOT_FOUND_99.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_038098000257_NOT_FOUND_86.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_038099002523_NOT_FOUND_7.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_038197008190_NOT_FOUND_87.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_040199002412_NOT_FOUND_83.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_051043408_NOT_FOUND_78.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_060098001058_NOT_FOUND_41.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_077202001430_NOT_FOUND_102.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_079301030356_NOT_FOUND_45.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_089098000366_NOT_FOUND_65.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_091872674_NOT_FOUND_81.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_092095001281_NOT_FOUND_70.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_094097000702_NOT_FOUND_62.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_122437442_NOT_FOUND_77.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_125846196_NOT_FOUND_74.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_142778849_NOT_FOUND_90.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_142808805_NOT_FOUND_91.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_142911873_NOT_FOUND_89.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_164531130_NOT_FOUND_97.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_174859591_NOT_FOUND_36.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_197342233_NOT_FOUND_82.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_231162130_NOT_FOUND_118.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_241589631_NOT_FOUND_127.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_241598903_NOT_FOUND_126.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_241687961_NOT_FOUND_128.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_250984080_NOT_FOUND_122.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_261510415_NOT_FOUND_51.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_261593289_NOT_FOUND_52.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_281206027_NOT_FOUND_55.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_285719085_NOT_FOUND_56.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_285830334_NOT_FOUND_54.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_285832539_NOT_FOUND_53.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_301689473_NOT_FOUND_50.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_331764456_NOT_FOUND_49.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_331780700_NOT_FOUND_40.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_334992364_NOT_FOUND_100.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_341879017_NOT_FOUND_59.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_363838216_NOT_FOUND_72.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_363946599_NOT_FOUND_71.pdf
# D:/Data science/CIC_check/2807\UNKNOWN_371823301_NOT_FOUND_109.pdf
# D:/Data science/CIC_check/2807\VO MINH TAN_371807309_SUCCESS_111.pdf
# D:/Data science/CIC_check/2807\VU GIA HUY_272885636_SUCCESS_46.pdf
# D:/Data science/CIC_check/2807\VÕ THỊ TƯỜNG VY_212164883_SUCCESS_4.pdf
# D:/Data science/CIC_check/2807\VÕ VĂN THỌ_221462565_SUCCESS_39.pdf
# D:/Data science/CIC_check/2807\VŨ ĐỨC THÀNH ĐẠT_031096006236_SUCCESS_95.pdf
# D:/Data science/CIC_check/2807\Đinh Thị Kim Trinh_245214157_SUCCESS_124.pdf
# D:/Data science/CIC_check/2807\ĐOÀN  THỊ  HỒNG_030300001594_SUCCESS_98.pdf
# D:/Data science/CIC_check/2807\ĐÀO TRUNG HẬU_079098010772_SUCCESS_44.pdf
# D:/Data science/CIC_check/2807\ĐẶNG HỮU MINH_082314341_SUCCESS_27.pdf
# D:/Data science/CIC_check/2807\ĐẶNG NGUYỄN DŨNG NAM_352522698_SUCCESS_66.pdf
